# %% [markdown]
# - Mice CA1 neural code during navigation in circular track: [https://github.com/schultzlab/Neural_Manifolds/blob/main/Neural_Manifold_Learning_CA1.ipynb](https://github.com/schultzlab/Neural_Manifolds/blob/main/Neural_Manifold_Learning_CA1.ipynb)
#
#     - methods: CA2+-imaging, navigation in circular track
#
#     - techniques: PCA, MDS, ISOMAP, LLE, Spectral embedding, tSNE, UMAP, Linear decoding
