# %% [markdown]
# # Figshare
#
#
# * **Authors**:
#
#   * author: steevelaquitaine@epfl.ch; laquitainesteeve@gmail.com
#
# * **Learning outcomes**:
#
#   * Know how to retrieve and share standardized, repropducible datasets and code
#
# * **Requirements**:
#
#   * You don't need an account to download public datasets such as the one used in the case study mice V1 (https://figshare.com/s/60adb075234c2cc51fa3).
#
#   * Just click `Download`

# %% [markdown]
# # Sign up
#
# https://figshare.com/account/register
#
# You need an email adress to activate the account

# %% [markdown]
# # Login

# %% [markdown]
# # Upload file
#
# My data - drag file to upload

# %% [markdown]
# # Fill up informations

# %% [markdown]
# Publish and Get private link you can share
