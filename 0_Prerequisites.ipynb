# %% [markdown]
# # **PREREQUISITES**
#
# author: steevelaquitaine@epfl.ch; laquitainesteeve@gmail.com
#
# **Learning outcomes**:
#
# * Setup your working environment

# %% [markdown]
# # **1. Setup a Google account**
#
# ## Ensure you have about 3 GB of free space

# %% [markdown]
# # **2. Setup a Github account**
#
# ## Github is necessary to login to <u>Dandi archive</u>.

# %% [markdown]
# # **3. Setup a Dandi Archive account**
#
# ## 1. Go to [dandiarchive.org](https://dandiarchive.org/)
#
# ## 2. Click login and follow instructions for registrations
#
# Your DANDI account requires up to 2 business days for approval and contact the DANDI admins at help@dandiarchive.org if you have any questions.

# %% [markdown]
# # **4. Practice Python basics**
#
#
# ## - See [Python Workshop 1](https://compneuro.neuromatch.io/tutorials/W0D1_PythonWorkshop1/chapter_title.html)
#
# ## - See [Python Workshop 2](https://compneuro.neuromatch.io/tutorials/W0D2_PythonWorkshop2/student/W0D2_Tutorial1.html)

# %% [markdown]
# # **5. Readings**
#
#
# * Schneider, S., Lee, J. H., & Mathis, M. W. (2023). Learnable latent embeddings for joint behavioural and neural analysis. Nature, 617(7960), 360-368.
# * Gokcen, Disentangling communication across populations of neurons, Thesis

# %% [markdown]
# # **4. Download required Datasets**
#
# ## Allen Institute's Mouse V1 Coding
#
# We will do this in class.
#
# Size:
#   * compressed: 3.16 GBs
#   * uncompressed: 12.4 GB
#
# Online source: Figshare: https://figshare.com/s/60adb075234c2cc51fa3
#
# Offline source: my hard drive
